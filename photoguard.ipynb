# %%
# !git clone https://github.com/vijay-murugan/photoguard.git
# Out:
# Cloning into 'photoguard'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 102 (delta 31), reused 24 (delta 14), pack-reused 57 (from 1)
# Receiving objects: 100% (102/102), 19.90 MiB | 11.96 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Filtering content: 100% (6/6), 4.13 MiB | 2.35 MiB/s, done.

# %%
# !pip install -r photoguard/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.1/503.1 kB 38.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.35.2
#     Uninstalling diffusers-0.35.2:
#       Successfully uninstalled diffusers-0.35.2
# ...

# %%
# %cd photoguard
# Out:
# /content/photoguard

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.50 KiB | 1.50 MiB/s, done.
# From https://github.com/vijay-murugan/photoguard
#    b0e6f1d..354fbae  main       -> origin/main
# Updating b0e6f1d..354fbae
# Fast-forward
#  demo/app.py | 118 +++++++++++++++++++++++++++++++++++++++++++++++++++++-------
#  1 file changed, 105 insertions(+), 13 deletions(-)

# %%
# !python -m pip install --upgrade "huggingface-hub>=0.34.0,<1.0"

# %%
# !python -m pip install --upgrade transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 93.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.2
#     Uninstalling transformers-4.57.2:
#       Successfully uninstalled transformers-4.57.2
# ...

# %%
# !python -m pip install --upgrade diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 77.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.10.2
#     Uninstalling diffusers-0.10.2:
#       Successfully uninstalled diffusers-0.10.2
# ...

# %%
# !python -c "from diffusers import StableDiffusionInpaintPipeline; print('import ok')"
# Out:
# 2025-12-01 16:38:25.512068: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764607105.531761    1174 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764607105.537675    1174 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764607105.552709    1174 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python demo/app.py
# Out:
# 2025-12-01 16:39:08.884191: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764607148.903811    1419 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764607148.909961    1419 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764607148.925472    1419 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
